# %% [markdown]
# # Neural style transfer
#
# Based on the paper by Gatis et al. 2016 ([ref](https://www.cv-foundation.org/openaccess/content_cvpr_2016/papers/Gatys_Image_Style_Transfer_CVPR_2016_paper.pdf)).

# %% [markdown]
# # Setup

# %%
import skimage
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
import torchvision
from im_func import show_image, show_multi_image
import skimage.io

# %% [markdown]
# # Import some images for content and style

# %%
content_im = skimage.io.imread("./Data/Cecile.jpg")
style_im = skimage.io.imread("./Data/Pollock.jpeg")
_ = show_multi_image(((content_im, 'Content'),
                      (style_im, 'Style')),figsize=[15,15])

# %% [markdown]
# # Import and initialize a pretrained model

# %%
# Import VGG

# %% [markdown]
# # Compute the style Gram matrix

# %% [markdown]
# # Run, compute loss, optimize
